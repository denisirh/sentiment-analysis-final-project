# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns", None)
# display the dataframe head

# %% [markdown]
# ## Import & Merge Dataset

# %%
data = pd.read_csv('C:/Users/User/Downloads/Final Project/20191002-items.csv')

data1 = pd.read_csv('C:/Users/User/Downloads/Final Project/20191002-reviews.csv')
print(data.shape,data1.shape)
# Out:
# (10942, 9) (203787, 15)

# %%
data.columns
# Out:
# Index(['itemId', 'category', 'name', 'brandName', 'url', 'price',
#        'averageRating', 'totalReviews', 'retrievedDate'],
#       dtype='object')

# %%
data1.columns
# Out:
# Index(['itemId', 'category', 'name', 'rating', 'originalRating', 'reviewTitle',
#        'reviewContent', 'likeCount', 'upVotes', 'downVotes', 'helpful',
#        'relevanceScore', 'boughtDate', 'clientType', 'retrievedDate'],
#       dtype='object')

# %%
df =pd.merge(data, data1, how="inner",on=["itemId",'category'])
df
# Out:
#            itemId                 category  \
# 0       100002528  beli-harddisk-eksternal
# 1       100002528  beli-harddisk-eksternal
# 2       100002528  beli-harddisk-eksternal
# 3       100002528  beli-harddisk-eksternal
# 4       100002528  beli-harddisk-eksternal
# ...           ...                      ...
# 203782    9467899    shop-televisi-digital
# 203783    9467899    shop-televisi-digital
# 203784    9548087    shop-televisi-digital
# 203785    9548767    shop-televisi-digital
# 203786    9548767    shop-televisi-digital
#
#                                                    name_x brandName  \
# 0       TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free B...   Toshiba
# 1       TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free B...   Toshiba
# 2       TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free B...   Toshiba
# 3       TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free B...   Toshiba
# 4       TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free B...   Toshiba
# ...

# %% [markdown]
# ## Handling Missing Values

# %%
print(df.isnull().sum())
df=df[df['reviewContent'].notna()]
print(df.isnull().sum())
# Out:
# itemId                  0
# category                0
# name_x                  0
# brandName               3
# url                     0
# price                   0
# averageRating           0
# totalReviews            0
# retrievedDate_x         0
# name_y                  0
# rating                  0
# originalRating     203779
# reviewTitle        180383
# reviewContent       96758
# likeCount               0
# upVotes                 0
# downVotes               0
# helpful                 0
# relevanceScore          0
# boughtDate           7107
# clientType              0
# retrievedDate_y         0
# dtype: int64
# itemId                  0
# category                0
# name_x                  0
# brandName               0
# url                     0
# price                   0
# averageRating           0
# totalReviews            0
# retrievedDate_x         0
# name_y                  0
# rating                  0
# originalRating     107021
# reviewTitle         85951
# ...

# %%
df.nunique()
# Out:
# itemId              3293
# category               5
# name_x              3208
# brandName            203
# url                 3293
# price               1494
# averageRating          5
# totalReviews         217
# retrievedDate_x        1
# name_y             22812
# rating                 5
# originalRating         1
# reviewTitle         5009
# reviewContent      38071
# likeCount            125
# upVotes              125
# downVotes             57
# helpful                1
# relevanceScore      2791
# boughtDate          1492
# clientType             5
# retrievedDate_y        1
# dtype: int64

# %%
df.columns
# Out:
# Index(['itemId', 'category', 'name_x', 'brandName', 'url', 'price',
#        'averageRating', 'totalReviews', 'retrievedDate_x', 'name_y', 'rating',
#        'originalRating', 'reviewTitle', 'reviewContent', 'likeCount',
#        'upVotes', 'downVotes', 'helpful', 'relevanceScore', 'boughtDate',
#        'clientType', 'retrievedDate_y'],
#       dtype='object')

# %% [markdown]
# ## Handling Outlier

# %%
sns.boxplot(df.price)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
pd.set_option('display.max_colwidth', None)

# %%
df.reviewContent[df.price==df.price.max()]
# Out:
# 81822                                                    Produk bagus bgt, Ayam peliharaan saya pada suka dibikinin kandang dari kardusnya. Saya cuma butuh kardusnya buat kandang ayam, TV nya malah buat main karambol anak saya.....
# 81823                                                                                       belom juga di transfer buat pembayarannya, ni TV dah di kirim aja ke rumah Via Gojek. mantab jiwa, layarnya bikin ane merem melek keenakan.
# 81824                    Barang udah nyampe dgn selamat..tengkyu lazada..mahal mahal dikit gapapa lah yg penting gambarnya tajam memuaskan,sekarang tinggal bingung mo dipajang dimane,,soalnya kudu jual rumah buat beli tipi ini nih.
# 81825     Terimakasih Lazada. Tadinya bingung mau naroh dimana. Karena q seorang artistek pintu rumah langsung gw ganti sama tv ini.. alhmdllah pas.. Sekarang pintu rumah gw bisa buat nnton film.. next time pesen buat ganti jendela
# ...

# %%
df = df[df.price != 275000000]

# %%
sns.boxplot(df.price)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
df.price.sort_values(ascending=False).unique()
# Out:
# array([74329000, 59345000, 37650000, ...,     3250,     3000,     1000],
#       dtype=int64)

# %%
df[df.price==df.price.max()]
# Out:
#            itemId                 category  \
# 5628    111304588  beli-harddisk-eksternal
# 5629    111304588  beli-harddisk-eksternal
# 5630    111304588  beli-harddisk-eksternal
# 82483   111304588              beli-laptop
# 82484   111304588              beli-laptop
# 82485   111304588              beli-laptop
# 88601   111304588            beli-smart-tv
# 88602   111304588            beli-smart-tv
# 88603   111304588            beli-smart-tv
# 120709  111304588        jual-flash-drives
# 120710  111304588        jual-flash-drives
# 120711  111304588        jual-flash-drives
# 183107  111304588    shop-televisi-digital
# 183108  111304588    shop-televisi-digital
# 183109  111304588    shop-televisi-digital
#
#                                                 name_x brandName  \
# 5628    Notebook Gaming MSI GT72VR 6RE Dominator Tobii    Import
# 5629    Notebook Gaming MSI GT72VR 6RE Dominator Tobii    Import
# 5630    Notebook Gaming MSI GT72VR 6RE Dominator Tobii    Import
# ...

# %%
df[df.price==59345000]
# Out:
#            itemId                 category  \
# 5728    111630530  beli-harddisk-eksternal
# 5729    111630530  beli-harddisk-eksternal
# 5730    111630530  beli-harddisk-eksternal
# 5731    111630530  beli-harddisk-eksternal
# 5732    111630530  beli-harddisk-eksternal
# ...           ...                      ...
# 183164  111630530    shop-televisi-digital
# 183165  111630530    shop-televisi-digital
# 183166  111630530    shop-televisi-digital
# 183167  111630530    shop-televisi-digital
# 183169  111630530    shop-televisi-digital
#
#                                                                                   name_x  \
# 5728    Laptop Gaming Asus G752VY-GC346T - 17.3" FHD - Intel i7-6700HQ - Ram 32GB - Gray
# 5729    Laptop Gaming Asus G752VY-GC346T - 17.3" FHD - Intel i7-6700HQ - Ram 32GB - Gray
# 5730    Laptop Gaming Asus G752VY-GC346T - 17.3" FHD - Intel i7-6700HQ - Ram 32GB - Gray
# ...

# %%
df = df[df.price < 40000000]

# %%
sns.boxplot(df.price)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['itemId', 'category', 'name_x', 'brandName', 'url', 'price',
#        'averageRating', 'totalReviews', 'retrievedDate_x', 'name_y', 'rating',
#        'originalRating', 'reviewTitle', 'reviewContent', 'likeCount',
#        'upVotes', 'downVotes', 'helpful', 'relevanceScore', 'boughtDate',
#        'clientType', 'retrievedDate_y'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
# plt.bar(df.value_counts('category').index,df.value_counts('category'))
plt.pie(df.value_counts('category'),labels=(df.value_counts('category').index),autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x29bdf79ba00>,
# ...
#  [Text(0.3621445256907124, 1.0386776894264405, 'beli-harddisk-eksternal'),
#   Text(-1.0541148460533991, -0.31439130288514494, 'jual-flash-drives'),
#   Text(0.20025625449500156, -1.0816179697728923, 'beli-smart-tv'),
#   Text(0.9475230625899295, -0.5587486428262719, 'shop-televisi-digital'),
#   Text(1.0954937166592402, -0.09946615886885525, 'beli-laptop')],
#  [Text(0.1975333776494795, 0.5665514669598766, '39.3%'),
#   Text(-0.5749717342109448, -0.17148616521007906, '30.6%'),
#   Text(0.10923068427000084, -0.5899734380579411, '16.0%'),
#   Text(0.5168307614126887, -0.30477198699614827, '11.2%'),
#   Text(0.5975420272686764, -0.05425426847392104, '2.9%')])

# %%
bestbrand=df.value_counts('brandName')
# plt.figure(figsize=(8, 6))
# plt.bar(bestbrand.index,bestbrand)

# %%
brand = pd.DataFrame(data ={
    'brandName' : bestbrand.index,
    'value' : bestbrand
})
brand
# Out:
#           brandName  value
# brandName
# SanDisk     SanDisk  18817
# Coocaa       Coocaa  17631
# Samsung     Samsung   8659
# Sharp         Sharp   7147
# Asus           Asus   7026
# ...             ...    ...
# SUNSKY       SUNSKY      1
# Hitachi     Hitachi      1
# Beauties   Beauties      1
# Sharkoon   Sharkoon      1
# Canon         Canon      1
#
# [203 rows x 2 columns]

# %%
#the top 5
df2 = brand[:5].copy()

#others
new_row = pd.DataFrame(data = {
    'brandName' : ['Others'],
    'value' : [brand['value'][5:].sum()]
})

#combining top 5 with others
df2 = pd.concat([df2, new_row])

# %%
plt.figure(figsize=(10, 6))
plt.pie(df2.value,labels=(df2.brandName),autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x29bdf8161f0>,
# ...
#  [Text(0.9346844789280043, 0.5799697620144392, 'SanDisk'),
#   Text(-0.06625309364086923, 1.098002972483688, 'Coocaa'),
#   Text(-0.8162939228831639, 0.7373359013801074, 'Samsung'),
#   Text(-1.0606947872670525, 0.2914216331443197, 'Sharp'),
#   Text(-1.0876211123266861, -0.16456097964360214, 'Asus'),
#   Text(0.19559388704314706, -1.082470799306546, 'Others')],
#  [Text(0.5098278975970932, 0.31634714291696675, '17.7%'),
#   Text(-0.03613805107683776, 0.5989107122638297, '16.6%'),
#   Text(-0.44525123066354394, 0.402183218934604, '8.1%'),
#   Text(-0.5785607930547558, 0.15895725444235617, '6.7%'),
#   Text(-0.5932478794509196, -0.0897605343510557, '6.6%'),
#   Text(0.10668757475080748, -0.5904386178035705, '44.3%')])

# %%
df.brandName.nunique()
# Out:
# 203

# %%
plt.figure(figsize=(10, 6))
plt.pie(df.value_counts('rating'),labels=df.value_counts('rating').index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x29be197a790>,
# ...
#  [Text(-0.8356521859285134, 0.7153219024697186, '5'),
#   Text(0.4942655739751661, -0.9827011460169363, '4'),
#   Text(0.9144293280808452, -0.6114073960507953, '1'),
#   Text(1.0641104790124167, -0.27869138568668633, '3'),
#   Text(1.0977759035282861, -0.06991470255000157, '2')],
#  [Text(-0.4558102832337345, 0.390175583165301, '77.5%'),
#   Text(0.2695994039864542, -0.5360188069183288, '9.9%'),
#   Text(0.4987796334986428, -0.3334949433004338, '6.5%'),
#   Text(0.5804238976431363, -0.1520134831018289, '4.1%'),
#   Text(0.5987868564699742, -0.03813529230000085, '2.0%')])

# %%
bestitem=df.value_counts('name_x').head(10)
bestitem
# Out:
# name_x
# [GRATIS ONGKIR] COOCAA LED TV 40 inch - Full HD Panel - Slim - USB/HDMI (Model : 40D3A)                                 3952
# [GRATIS ONGKIR] COOCAA LED TV 24 inch - HD Panel - USB/HDMI/VGA - Slim (Model : 24D3A)                                  3540
# Philips 32 inch LED HD TV - Hitam (Model 32PHA4100)                                                                     3280
# [GRATIS ONGKIR] Sharp 24 inch LED AQUOS HD TV - Hitam (Model LC-24LE170i)                                               3276
# [GRATIS ONGKIR] COOCAA LED TV 40 inch Android Smart TV - Wifi - Full HD - Slim - Infinity View (Model : 40S5G)          2886
# [GRATIS ONGKIR][Android 9.0 Ready] Xiaomi LED TV 32 inch - Smart TV Android Certified - PatchWall 2.0 (Model : 4A32)    2742
# SanDisk Flashdisk Cruzer Blade CZ50 - 16GB                                                                              1930
# ...

# %% [markdown]
# ## Set Satisfaction Rating

# %%
label=[]
for index, row in df.iterrows():
    if row['rating']==5:
        label.append(1)   
    elif row['rating']==4:
        label.append(1) 
    else:
        label.append(0)

df['label']=label
df.head()
# Out:
#       itemId                 category  \
# 0  100002528  beli-harddisk-eksternal
# 1  100002528  beli-harddisk-eksternal
# 2  100002528  beli-harddisk-eksternal
# 3  100002528  beli-harddisk-eksternal
# 7  100002528  beli-harddisk-eksternal
#
#                                                                                  name_x  \
# 0  TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free Bracket TV - Hitam - Khusus Jabodetabek
# 1  TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free Bracket TV - Hitam - Khusus Jabodetabek
# 2  TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free Bracket TV - Hitam - Khusus Jabodetabek
# 3  TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free Bracket TV - Hitam - Khusus Jabodetabek
# 7  TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free Bracket TV - Hitam - Khusus Jabodetabek
#
#   brandName  \
# 0   Toshiba
# 1   Toshiba
# 2   Toshiba
# 3   Toshiba
# 7   Toshiba
#
# ...

# %%
df.label.value_counts()
# Out:
# 1    93001
# 0    13445
# Name: label, dtype: int64

# %%
93001/(93001+13445)
# Out:
# 0.873691824962892

# %% [markdown]
# ## Take Sample Dataset

# %%
s1=df[df.label==1].sample(5000, replace=True)
s2=df[df.label==0].sample(5000, replace=True)

data=pd.concat([s1,s2])
print(data.shape)
print(data.label.value_counts(normalize=False))
# Out:
# (10000, 23)
# 1    5000
# 0    5000
# Name: label, dtype: int64

# %%
data.drop_duplicates()
# Out:
#            itemId                 category  \
# 48451   389216525  beli-harddisk-eksternal
# 166467  466140285        jual-flash-drives
# 154663  392480709        jual-flash-drives
# 34111   338487257  beli-harddisk-eksternal
# 123195  142877990        jual-flash-drives
# ...           ...                      ...
# 49347   390739847  beli-harddisk-eksternal
# 111573  421925893            beli-smart-tv
# 33298      336113  beli-harddisk-eksternal
# 77342   724216967  beli-harddisk-eksternal
# 61814     4299521  beli-harddisk-eksternal
#
#                                                                                                                       name_x  \
# 48451   [GRATIS ONGKIR][Android 9.0 Ready] Xiaomi LED TV 43 inch - Smart TV Android Certified - PatchWall 2.0 (Model : 4A43)
# 166467      ACER A314-32-C3X0 - Intel CeleronN4000 - 4GB - 1TB  - 14" - W10 - Black - Laptop Murah (Gratis Tas) - Bergaransi
# ...

# %% [markdown]
# ## Make a New Dataset for Sentiment Analysis

# %%
dfr=data.loc[:,['reviewContent','label']]
dfr.head()
# Out:
#                                                                                                                                                                                    reviewContent  \
# 48451                                                                                                                   to the point, mantap jiwa,.. tinggal menanti free hooq nya. jgn lama2 ya
# 166467                                                                                                                                                       barang nya ok cepat sekali sampenya
# 154663         Ngga rugi beli Smart Tv ini ... sale murah . kwalitas barang kyk tv mahal, bezelessss kyk smartphone juga. warna bagus . paking kayu lagi... - masi belum bisa masuk akun youtube
# 34111                                                                                               Packing ok, pengiriman cepat sekali. Barang oke dan ori. Smoga awett. Thx seller dan Lazada.
# ...

# %% [markdown]
# ## Remove Punctuation / Everything Besides Words

# %%
import re
dfr.reviewContent = dfr.reviewContent.apply(lambda x: x.lower())
dfr.reviewContent = dfr.reviewContent.apply(lambda x: re.sub(r'([^a-z\s]+)','',x))
dfr.reviewContent
# Out:
# 48451                                                                                                                   to the point mantap jiwa tinggal menanti free hooq nya jgn lama ya
# 166467                                                                                                                                                 barang nya ok cepat sekali sampenya
# 154663              ngga rugi beli smart tv ini  sale murah  kwalitas barang kyk tv mahal bezelessss kyk smartphone juga warna bagus  paking kayu lagi  masi belum bisa masuk akun youtube
# 34111                                                                                              packing ok pengiriman cepat sekali barang oke dan ori smoga awett thx seller dan lazada
# 123195    proses pengiriman cepat untuk kualitas flashdisk sangat mulus untuk kecepatan saat memindahakan file sesuai standar  format ini itu tidak ada masalah dan barang original thanks
# ...

# %% [markdown]
# ## Remove Stopwords

# %%
from nltk.corpus import stopwords
from string import punctuation
manualwords=['nya', 'yg', 'ya', 'aja']
stop_words=stopwords.words("indonesian")+list(punctuation)+manualwords

# %%
dfr.reviewContent=dfr.reviewContent.apply(lambda x: re.split(r'\s+', x))
dfr.reviewContent=dfr.reviewContent.apply(lambda x: [w for w in x if not w in stop_words])
dfr.reviewContent=dfr.reviewContent.apply(lambda x: str(' '.join(x)))

# %%
# sentences=[word_tokenize(review) for review in tqdm(token)]
# sentences

# %% [markdown]
# ## Stemming

# %%
from tqdm import tqdm
tqdm.pandas()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\tqdm\std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stem
dfr.reviewContent=dfr.reviewContent.progress_apply(lambda x:stemmer.stem(x))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 10000/10000 [22:08<00:00,  7.53it/s]

# %%
# %%time
# Out:
# UsageError: %%time is a cell magic, but the cell body is empty. Did you mean the line magic %time (single %)?

# %% [markdown]
# ## Word Visualisation

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
trains1=dfr[dfr['label']==0]
all_text=' '.join(word for word in trains1['reviewContent'])
word_cloud=WordCloud(colormap='Reds', width=1000, height=1000,mode='RGBA',background_color='white').generate(all_text)
plt.figure(figsize=(20,20))
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %%
trains2=dfr[dfr['label']==1]
all_text=' '.join(word for word in trains2['reviewContent'])
word_cloud=WordCloud(colormap='Blues', width=1000, height=1000,mode='RGBA',background_color='white').generate(all_text)
plt.figure(figsize=(20,20))
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(dfr.reviewContent, dfr['label'], 
                                                    test_size=0.1, random_state=30)

# %% [markdown]
# ## Word Transformation

# %% [markdown]
# ### Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
cv = CountVectorizer()

emb = cv.fit_transform(dfr.reviewContent)
sumword=pd.Series(sum(emb.toarray()))
sumword=sumword.sort_values(ascending=False).head(100)
jumlah=[]
kata=[]
for i in sumword.index:
    kata.append(cv.get_feature_names()[i])
    jumlah.append(sumword[i])
dummy={'kata':kata,
     'jumlah':jumlah}
jmlhkt=pd.DataFrame(dummy)

# %%
cek=pd.DataFrame(emb.toarray())

# %%
cek

# %% [markdown]
# ### TF-IDF

# %%
tf = TfidfVectorizer()
X_train = tf.fit_transform(X_train)
X_test = tf.transform(X_test)

# %%
print(X_train.shape)
print(X_test.shape)

# %% [markdown]
# ## Machine Learning Model

# %% [markdown]
# ## Comparation

# %%
# spot check machine learning algorithms on the credit card fraud dataset
from numpy import mean
from numpy import std
from pandas import read_csv
from matplotlib import pyplot
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.metrics import make_scorer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn import svm

# calculate precision-recall area under curve
def pr_auc(y_true, probas_pred):
    # calculate precision-recall curve
    p, r, _ = precision_recall_curve(y_true, probas_pred)
    # calculate area under curve
    return auc(r, p)

# evaluate a model
def evaluate_model(X, y, model):
    # define evaluation procedure
    cv = RepeatedStratifiedKFold(n_splits=2, n_repeats=3, random_state=1)
    # define the model evaluation the metric
    metric = make_scorer(pr_auc, needs_proba=True)
    # evaluate model
    scores = cross_val_score(model, X, y, scoring=metric, cv=cv, n_jobs=-1)
    return scores

# define models to test
def get_models():
    models, names = list(), list()
    #svm
    models.append(svm.SVC(kernel="linear",probability=True))
    names.append('SVM')
    # CART
    models.append(DecisionTreeClassifier())
    names.append('CART')
    # Bagging
    models.append(BaggingClassifier(n_estimators=100))
    names.append('BAG')
    # RF
    models.append(RandomForestClassifier(n_estimators=100))
    names.append('RF')
    return models, names


# load the dataset
X, y = X_train, y_train
# define models
models, names = get_models()
results = list()
# evaluate each model
for i in range(len(models)):
    # evaluate the model and store results
    scores = evaluate_model(X, y, models[i])
    results.append(scores)
    # summarize performance
    print('>%s %.3f (%.3f)' % (names[i], mean(scores), std(scores)))

# %%
# plot the results
plt.figure(figsize=(10, 6))
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rfc=RandomForestClassifier()

rfc.fit(X_train, y_train)

# %%
pred=rfc.predict(X_test)
print("Accuracy for Random Forest on CV data: ",accuracy_score(y_test,pred))

# %% [markdown]
# ## Evaluation Score

# %%
from sklearn.metrics import confusion_matrix
CF=confusion_matrix(y_test, pred)
CF

# %%
from sklearn.metrics import classification_report
target_names = ['0','1']
print(classification_report(y_test, pred))

# %%
sns.heatmap(CF,annot=True,fmt='g')
plt.xlabel("Predicted Label")
plt.ylabel("Actual Label")

# %%
from sklearn.metrics import roc_curve
# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, pred)
# Plot ROC curve
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
plt.bar([x for x in range(len(rfc.feature_importances_))], rfc.feature_importances_)

# %%
fi=pd.Series(rfc.feature_importances_)

# %%
topfi=fi.sort_values(ascending=False).head(10)
kiit=[]
fhgf=[]
for i in topfi.index:
    kiit.append(tf.get_feature_names()[i])

for i in kiit:
    fhgf.append(int(jmlhkt.jumlah[jmlhkt.kata==i]))

dummy={'kata':kiit,
      'feature_importances':topfi,
      'banyak_kata':fhgf}
pd.DataFrame(dummy)

# %%
coba = ['pelayanannya buruk, barang pecah kecewa sama lazada nyesel',
       'barang sampai dengan selamat. pelayanan bagus']

# %%
cobatf = tf.transform(coba)
predcoba=rfc.predict(cobatf)
predcoba
